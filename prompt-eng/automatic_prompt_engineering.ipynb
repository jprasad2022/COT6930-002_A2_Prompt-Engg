# %% [markdown]
# # Automatic Prompt Engineering
#
# Automatic Prompt Engineering refers to methods that automatically generate, refine, or optimize prompts for language models without relying solely on human intuition. Instead of manually crafting prompts through trial and error, these approaches use optimization techniques (such as gradient-based methods) or search strategies to discover prompts that effectively elicit the desired behavior from a model.
#
# One influential paper in this area is "AutoPrompt: Eliciting Knowledge from Language Models with Automatically Generated Prompts" by Shin et al. (2020). This work demonstrates how to automatically generate prompts that can tap into a language model’s latent knowledge by iteratively modifying discrete prompt tokens based on gradient signals. It’s a seminal work that has inspired further research into automated methods for prompt engineering.
#
# ## References:
# * (Shin et al. (2020),)[https://arxiv.org/abs/2010.15980]

# %% [markdown]
# ## Running this code on MyBind.org
#
# Note: remember that you will need to **adjust CONFIG** with **proper URL and API_KEY**!
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/GenILab-FAU/prompt-eng/HEAD?urlpath=%2Fdoc%2Ftree%2Fprompt-eng%2Fchain_of_thought.ipynb)

# %%
from _pipeline import create_payload, model_req

# Define the prompt as a string variable using Automatic Prompt Engineering
PROMPT = """
You are an expert in Automatic Prompt Engineering as well as in Surplus Lines Tax regulations across all 50 states.
Your task is twofold:

Step 1: Automatically design an optimal prompt that encapsulates all the necessary components for a comprehensive requirements analysis on Surplus Lines Tax regulations. The optimal prompt should include:
- A general overview of the surplus lines tax regulatory framework.
- Detailed, state-specific requirements such as tax rates, filing deadlines, and documentation mandates.
- Information on compliance obligations, exemptions, and any unique conditions for each state.
- Key challenges and considerations for businesses.

Step 2: Without exposing any internal reasoning or the automatically generated prompt, use it to produce a final, well-organized, and comprehensive requirements analysis covering all 50 states.

Your final output should only include the consolidated requirements analysis. Do not include any internal prompt engineering details or intermediate steps.

Now, please design the optimal prompt internally and generate the final comprehensive requirements analysis for Surplus Lines Tax regulations.
"""

# You can then use this PROMPT variable with your LLM or orchestration setup
print(PROMPT)

# Count the number of words
word_count = len(PROMPT.split())
print("Number of words in the prompt:", word_count)

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
#                         model="deepseek-r1:14b", 
                         model="phi4",                         
                         prompt=PROMPT, 
                         temperature=0.3, 
                         num_ctx=word_count, 
                         num_predict=5000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# You are an expert in Automatic Prompt Engineering as well as in Surplus Lines Tax regulations across all 50 states.
# Your task is twofold:
#
# Step 1: Automatically design an optimal prompt that encapsulates all the necessary components for a comprehensive requirements analysis on Surplus Lines Tax regulations. The optimal prompt should include:
# - A general overview of the surplus lines tax regulatory framework.
# - Detailed, state-specific requirements such as tax rates, filing deadlines, and documentation mandates.
# - Information on compliance obligations, exemptions, and any unique conditions for each state.
# - Key challenges and considerations for businesses.
#
# Step 2: Without exposing any internal reasoning or the automatically generated prompt, use it to produce a final, well-organized, and comprehensive requirements analysis covering all 50 states.
#
# Your final output should only include the consolidated requirements analysis. Do not include any internal prompt engineering details or intermediate steps.
#
# Now, please design the optimal prompt internally and generate the final comprehensive requirements analysis for Surplus Lines Tax regulations.
#
# Number of words in the prompt: 163
# ### Comprehensive Requirements Analysis: Surplus Lines Tax Regulations Across 50 States
#
# #### Introduction
# Surplus lines insurance refers to coverage provided by non-admitted insurers that are not licensed in a particular state but can write policies under certain conditions. Each state has its own set of regulations and tax requirements for surplus lines, which can vary significantly. This analysis provides an overview of the key aspects of surplus lines tax regulations across all 50 states.
#
# #### General Taxation Framework
# 1. **Tax Rates**: Most states impose a premium tax on surplus lines insurance, often at rates similar to those applied to admitted insurers. However, some states have specific surcharges or additional fees.
# 2. **Payment and Reporting**: Insurers are typically required to report premiums annually and pay taxes within specified deadlines. Failure to comply can result in penalties.
#
# #### State-Specific Regulations
#
# - **Alabama**: Imposes a 3% tax on surplus lines premiums with an additional $1,000 annual fee for each line of authority.
#
# - **Alaska**: Charges a 5% premium tax plus a $500 registration fee per line of authority.
#
# - **Arizona**: Levies a 2.25% tax on gross receipts from insurance transactions and requires a $250 license fee.
#
# - **Arkansas**: Applies a 3% tax on surplus lines premiums with an additional $1,000 annual fee for each line of authority.
#
# - **California**: Charges a 2% tax on surplus lines premiums, plus a $500 registration fee per line of authority.
#
# - **Colorado**: Imposes a 3.5% tax on gross premium receipts from insurance transactions and requires a $250 license fee.
#
# - **Connecticut**: Applies a 1.25% tax on gross direct written premium for surplus lines insurers with an additional $100 registration fee.
#
# - **Delaware**: Charges a 2% tax on gross premiums for surplus lines insurance, plus a $500 annual filing fee.
#
# - **Florida**: Imposes a 3% tax on gross direct written premiums for surplus lines insurance and requires a $250 license renewal fee.
#
# - **Georgia**: Levies a 5% tax on gross premium receipts from non-admitted insurers with an additional $100 registration fee.
#
# - **Hawaii**: Applies a 2.75% tax on gross premiums for surplus lines insurance, plus a $200 annual licensing fee.
#
# - **Idaho**: Charges a 3% tax on gross direct written premiums for surplus lines insurance and requires a $150 license renewal fee.
#
# - **Illinois**: Imposes a 4% tax on gross premium receipts from non-admitted insurers with an additional $100 registration fee.
#
# - **Indiana**: Levies a 2.5% tax on gross direct written premiums for surplus lines insurance and requires a $250 annual licensing fee.
#
# - **Iowa**: Charges a 3.5% tax on gross premium receipts from non-admitted insurers and requires a $300 license renewal fee every two years.
#
# - **Kansas**: Imposes a 4% tax on gross direct written premiums for surplus lines insurance with no additional fees.
#
# - **Kentucky**: Levies a 2% tax on gross premium receipts from nonadmitted insurers and requires a $100 annual licensing fee.
#
# - **Louisiana**: Charges a 3% tax on gross direct written premiums for surplus lines insurance and mandates an additional $200 compliance fee annually.
#
# - **Maine**: Imposes a 5% tax on gross premium receipts from unauthorized insurers with no extra fees.
#
# - **Maryland**: Levies a 4% tax on gross premium receipts from nonadmitted insurers and requires a $150 annual licensing fee.
#
# - What is the total tax and additional fees for Louisiana?
# Time taken: 235.334s
